# %%
import math
import numpy as np
import bisect
from scipy import interpolate
import pylab as pl

class Spline:
    """
    Cubic Spline class
    """
    def __init__(self, x, y):
        self.b, self.c, self.d, self.w = [], [], [], []
        self.x = x
        self.y = y
        self.nx = len(x)  # dimension of x
        h = np.diff(x)
        # calc coefficient c
        self.a = [iy for iy in y]
        # calc coefficient c
        A = self.__calc_A(h)
        B = self.__calc_B(h)
        self.c = np.linalg.solve(A, B)
        #  print(self.c1)
        # calc spline coefficient b and d
        for i in range(self.nx - 1):
            self.d.append((self.c[i + 1] - self.c[i]) / (3.0 * h[i]))
            tb = (self.a[i + 1] - self.a[i]) / h[i] - h[i] * \
                (self.c[i + 1] + 2.0 * self.c[i]) / 3.0
            self.b.append(tb)
    def calc(self, t):
        """
        Calc position

        if t is outside of the input x, return None

        """

        if t < self.x[0]:
            return None
        elif t > self.x[-1]:
            return None

        i = self.__search_index(t)
        dx = t - self.x[i]
        result = self.a[i] + self.b[i] * dx + \
            self.c[i] * dx ** 2.0 + self.d[i] * dx ** 3.0

        return result

    def calcd(self, t):
        """
        Calc first derivative
        if t is outside of the input x, return None
        """
        if t < self.x[0]:
            return None
        elif t > self.x[-1]:
            return None

        i = self.__search_index(t)
        dx = t - self.x[i]
        result = self.b[i] + 2.0 * self.c[i] * dx + 3.0 * self.d[i] * dx ** 2.0
        return result

    def calcdd(self, t):
        """
        Calc second derivative
        """

        if t < self.x[0]:
            return None
        elif t > self.x[-1]:
            return None

        i = self.__search_index(t)
        dx = t - self.x[i]
        result = 2.0 * self.c[i] + 6.0 * self.d[i] * dx
        return result

    def __search_index(self, x):
        """
        search data segment index
        """
        return bisect.bisect(self.x, x) - 1

    def __calc_A(self, h):
        """
        calc matrix A for spline coefficient c
        """
        A = np.zeros((self.nx, self.nx))
        A[0, 0] = 1.0
        for i in range(self.nx - 1):
            if i != (self.nx - 2):
                A[i + 1, i + 1] = 2.0 * (h[i] + h[i + 1])
            A[i + 1, i] = h[i]
            A[i, i + 1] = h[i]

        A[0, 1] = 0.0
        A[self.nx - 1, self.nx - 2] = 0.0
        A[self.nx - 1, self.nx - 1] = 1.0
        #  print(A)
        return A

    def __calc_B(self, h):
        """
        calc matrix B for spline coefficient c
        """
        B = np.zeros(self.nx)
        for i in range(self.nx - 2):
            B[i + 1] = 3.0 * (self.a[i + 2] - self.a[i + 1]) / \
                h[i + 1] - 3.0 * (self.a[i + 1] - self.a[i]) / h[i]
        return B


class Spline2D:
    """
    2D Cubic Spline class

    """

    def __init__(self, x, y):
        self.s = self.__calc_s(x, y)
        self.sx = Spline(self.s, x)
        self.sy = Spline(self.s, y)

    def __calc_s(self, x, y):
        dx = np.diff(x)
        dy = np.diff(y)
        self.ds = [math.sqrt(idx ** 2 + idy ** 2)
                   for (idx, idy) in zip(dx, dy)]
        s = [0]
        s.extend(np.cumsum(self.ds))
        return s

    def calc_position(self, s):
        """
        calc position
        """
        x = self.sx.calc(s)
        y = self.sy.calc(s)

        return x, y

    def calc_curvature(self, s):
        """
        calc curvature
        """
        dx = self.sx.calcd(s)
        ddx = self.sx.calcdd(s)
        dy = self.sy.calcd(s)
        ddy = self.sy.calcdd(s)
        k = (ddy * dx - ddx * dy) / ((dx ** 2 + dy ** 2)**(3 / 2))
        return k

    def calc_yaw(self, s):
        """
        calc yaw
        """
        dx = self.sx.calcd(s)
        dy = self.sy.calcd(s)
        yaw = math.atan2(dy, dx)
        if yaw<0:
            yaw = yaw+2*math.pi
        return yaw



def calc_spline_course(x, y, ds=0.1):
    sp = Spline2D(x, y)
    s = list(np.arange(0, sp.s[-1], ds))

    rx, ry, ryaw, rk = [], [], [], []
    for i_s in s:
        ix, iy = sp.calc_position(i_s)
        rx.append(ix)
        ry.append(iy)
        ryaw.append(sp.calc_yaw(i_s))
        rk.append(sp.calc_curvature(i_s))

    return rx, ry, ryaw, rk, s

# %%
print("Spline 2D test")
import matplotlib.pyplot as plt
#     x = [0, 1.5，1.5，1.5 3, 5.0, 7.5, 3.0, -1.0]
#     y = [0, 1.2,  3, , 0.0, 5.0, -2.0]
x = [0,  1.5,  2.2,  1.5, 0.8, 1.5,  3]
y = [0,  1,     2,    3,   2, 1,   0]
ds = 0.1  # [m] distance of each intepolated points

sp = Spline2D(x, y)
s = np.arange(0, sp.s[-1], ds)
#     s = np.linespace()

rx, ry, ryaw, rk = [], [], [], []
for i_s in s:
    ix, iy = sp.calc_position(i_s)
    rx.append(ix)
    ry.append(iy)
    ryaw.append(sp.calc_yaw(i_s))
    rk.append(sp.calc_curvature(i_s))

plt.subplots(1)
plt.plot(x, y, "xb", label="input")
plt.plot(rx, ry, "-r", label="spline")
plt.grid(True)
plt.axis("equal")
plt.xlabel("x[m]")
plt.ylabel("y[m]")
plt.legend()

plt.subplots(1)
plt.plot(s, [iyaw for iyaw in ryaw], "-r", label="yaw")
plt.grid(True)
plt.legend()
plt.xlabel("line length[m]")
plt.ylabel("yaw angle[rad]")

plt.subplots(1)
plt.plot(s, rk, "-r", label="curvature")
plt.grid(True)
plt.legend()
plt.xlabel("line length[m]")
plt.ylabel("curvature [1/m]")


plt.subplots(1)
plt.plot(s, rx, "-r", label="x")
plt.grid(True)
plt.legend()
plt.xlabel("line length[m]")
plt.ylabel("x")


plt.subplots(1)
plt.plot(s, ry, "-r", label="y")
plt.grid(True)
plt.legend()
plt.xlabel("line length[m]")
plt.ylabel("y")

plt.show()
print(len(ryaw))
# Out:
# Spline 2D test
# 85

# %%
plt.figure(figsize=[12,12])
xnew=np.linspace(0,s[-1],1001)
plt.subplot(3,3,1)
plt.plot(s,ryaw,'ro')
list1=['cubic']
list2=[3]
kind = 'cubic'
print(kind)
fyaw=interpolate.interp1d(s,ryaw,kind=kind)
yawnew=fyaw(xnew)
plt.plot(xnew,yawnew,label=kind)

plt.legend(loc='lower right')


plt.subplot(3,3,2)
fx = interpolate.interp1d(s,rx,kind=kind)
plt.plot(s,rx,'ro')
x_new_=fx(xnew)
plt.plot(xnew,x_new_,label=kind)
plt.legend(loc='lower right')



plt.subplot(3,3,3)
fy= interpolate.interp1d(s,ry,kind=kind)
plt.plot(s,ry,'ro')
ynew_=fy(xnew)
plt.plot(xnew,ynew_,label="y")
plt.legend(loc='lower right')

plt.subplot(3,3,4)
plt.plot(x_new_,label="x")
plt.legend(loc='lower right')

plt.subplot(3,3,5)
plt.plot(ynew_,label="y")
plt.legend(loc='lower right')

plt.subplot(3,3,6)
plt.plot(yawnew,label="theta")
plt.legend(loc='lower right')

vx = x_new_[1:]-x_new_[:-1]
vx = np.concatenate([[vx[0]],vx])/0.01
vy = ynew_[1:]-ynew_[:-1]
vy = np.concatenate([[vy[0]],vy])/0.01
omg = yawnew[1:]-yawnew[:-1]
omg = np.concatenate([[omg[0]],omg])/0.01

plt.subplot(3,3,7)
plt.plot(vx,label="vx")
plt.legend(loc='lower right')

plt.subplot(3,3,8)
plt.plot(vy,label="vy")
plt.legend(loc='lower right')

plt.subplot(3,3,9)
plt.plot(omg,label="omg")
plt.legend(loc='lower right')

plt.show()
# Out:
# cubic

# %%
from __future__ import print_function




import numpy as np
import matplotlib.pyplot as plt
import quadrotor
import math



robot = quadrotor.Quadrotor()
horizon_length = 1000
N = 1000
u_ = robot.mass*robot.g/2
z0 = np.array([1,0,0,0,0,0]).reshape([6,])
u0 = u_ * np.ones([2,1])
o = (2*math.pi/10)/6
r = 1
T = 10
middle = 500
tau = 0.6
x = np.array(x_new_)
vx = np.array(vx)
y = np.array(ynew_)
vy = np.array(vy)
yawnew = np.array(yawnew)
omg = np.array(omg)
state_desired = np.array([x,vx,y,vy,yawnew,omg])

# %%
state_desired.shape
# Out:
# (6, 1001)

# %%
ref_traj = state_desired.T
z0 = np.zeros_like(state_desired[:,0])
u_init = [(robot.mass * robot.g / 2) * np.ones([2]) for _ in range(horizon_length)]
print(ref_traj.shape,state_desired.shape)
import solver
try:
    import jax.numpy as np
except ImportError:
    import numpy as np

class iLQR_Track_Controller:
    def __init__(self,R,dt,use_autograd = False):
        self.aux = None
        self.R_ = R
        self.dt_ = dt

        #desired functions for plant dynamics and cost
        self.plant_dyn_ = None
        self.plant_dyn_dx_ = None
        self.plant_dyn_du_ = None

        self.cost_ = None
        self.cost_dx_ = None
        self.cost_du_ = None
        self.cost_dxx_ = None
        self.cost_duu_ = None
        self.cost_dux_ = None

        self.ilqr_ = None

        self.use_autograd=use_autograd
        return

    def build_iLQR_tracking(self,ref_pnts, weight_mats,obj):
        #obj must have next_state,  get_linearization
        self.obj = obj
        #figure out dimension
        self.T_ = len(ref_pnts)# leave the last point alone


        self.ref_array = np.copy(ref_pnts)
        self.weight_array = [mat for mat in weight_mats]
        #clone weight mats if there are not enough weight mats
        for i in range(self.T_ - len(self.weight_array)):
            self.weight_array.append(self.weight_array[-1])


        def tmp_cost_func(x, u, t, aux):
            err = x - self.ref_array[t]
            #autograd does not allow A.dot(B)
            cost = np.dot(np.dot(err, self.weight_array[t]), err) + np.sum(u**2) * self.R_
            return cost

        self.cost_ = tmp_cost_func
        self.ilqr_ = solver.Solver(T=self.T_ - 1, plant_dyn=self.plant_dyn_, cost=self.cost_,
                                   use_autograd=self.use_autograd)
        if not self.use_autograd:
            self.plant_dyn = lambda x, u, t, aux:obj.next_state(x,u,t)
            self.plant_dyn_du_ = lambda x, u, t, aux: obj.get_linearization(x, u, t)[0]
            self.plant_dyn_dx_ = lambda x, u, t, aux: obj.get_linearization(x, u, t)[1]
            def tmp_cost_func_dx(x, u, t, aux):
                err = x - self.ref_array[t]
                grad = np.concatenate([2 * err.dot(self.weight_array[t])])
                return grad

            self.cost_dx_ = tmp_cost_func_dx

            self.cost_du_ = lambda x, u, t, aux: 2 * self.R_ * u

            def tmp_cost_func_dxx(x, u, t, aux):
                hessian = np.zeros((self.obj.ns,self.obj.ns))
                hessian = 2 * self.weight_array[t]
                return hessian

            self.cost_dxx_ = tmp_cost_func_dxx

            self.cost_duu_ = lambda x, u, t, aux: 2 * self.R_ * np.eye(self.obj.nu)
            self.cost_dux_ = lambda x, u, t, aux: np.zeros((self.obj.nu,self.obj.ns))

            # build an iLQR solver based on given functions...
            self.ilqr_.plant_dyn = self.plant_dyn
            self.ilqr_.plant_dyn_dx = self.plant_dyn_dx_
            self.ilqr_.plant_dyn_du = self.plant_dyn_du_
            self.ilqr_.cost_dx = self.cost_dx_
            self.ilqr_.cost_du = self.cost_du_
            self.ilqr_.cost_dxx = self.cost_dxx_
            self.ilqr_.cost_duu = self.cost_duu_
            self.ilqr_.cost_dux = self.cost_dux_
        return

    def synthesize_trajectory(self,x0, u_array=None, n_itrs=50, tol=1e-6, verbose=True):
        if self.ilqr_ is None:
            print('No iLQR solver has been prepared.')
            return None
        #initialization doesn't matter as global optimality can be guaranteed?
        if u_array is None:
            u_init = [np.zeros(self.obj.nu) for i in range(self.T_-1)]
        else:
            u_init = u_array
        x_init = np.zeros(self.obj.ns)
        x_init[:len(x0)] = x0

        # res = self.lqr_.ilqr_iterate(x_init, u_init, n_itrs=n_itrs, tol=tol, verbose=verbose)
        res_dict = self.ilqr_.LQR_solve(x_init, u_init)
        x_star = res_dict['x_array_star']
        Ks = res_dict['K_array_opt']
        ks = res_dict['k_array_opt']
        x_array_new, u_array_new = self.apply_control(x_star, u_init, ks, Ks,alpha=1)
        return x_array_new[:, 0:self.obj.nu]

    def get_rule(self,x0, u_array=None, n_itrs=50, tol=1e-6, verbose=True):
        if self.ilqr_ is None:
            print('No iLQR solver has been prepared.')
            return None
        #initialization doesn't matter as global optimality can be guaranteed?
        if u_array is None:
            u_init = [np.zeros(self.obj.nu) for i in range(self.T_-1)]
        else:
            u_init = u_array
        x_init = np.zeros(self.obj.ns)
        x_init[:len(x0)] = x0

        # res = self.lqr_.ilqr_iterate(x_init, u_init, n_itrs=n_itrs, tol=tol, verbose=verbose)
        res_dict = self.ilqr_.iLQR_iteration(x_init, u_init,n_itrs)
        # x_star = res_dict['x_array_star']
        # Ks = res_dict['K_array_opt']
        # ks = res_dict['k_array_opt']
        # xs = res_dict['x_array_opt']
        # us = res_dict['u_array_opt']
        return res_dict

    def controller(self,u,x,k_array,K_array):
        pass

    def apply_control(self, x_array, u_array, k_array, K_array,alpha=1) :
        x_new_array = [None] * len(x_array)
        u_new_array = [None] * len(u_array)
        x_new_array[0] = x_array[0]
        for t in range(self.T_ -1 ):
            u_new_array[t] = u_array[t] + alpha * (k_array[t] + K_array[t].dot(x_new_array[t]-x_array[t]))
            x_new_array[t+1] = self.obj.next_state(x_new_array[t], u_new_array[t], t)
        return np.array(x_new_array), np.array(u_new_array)
# Out:
# (1001, 6) (6, 1001)

# %%
q1c = 1
q2c = 1
q3c = 1
tau1 = 10
tau2 = 20

q1 =  np.array([1 if (400<i)and(i<5000) else 0 for i in range(N+1)])
weight_mats = [100*np.diag([10,0,10,0,10*q1[i],2*q1[i]]) for  i in range(len(ref_traj))]
q2 = [q1c*(math.e**(-abs(i-middle)/tau1)) for  i in range(len(ref_traj))]
q3 = q1*q2

q4 = np.array([1 if (550<i)and(i<750) else 0 for i in range(N+1)])
q5 = [q2c*(math.e**(-abs(i-600)/tau2)) for  i in range(len(ref_traj))]
q6 = q4*q5


# q7 = np.array([1 if (750<i)and(i<900) else 0 for i in range(N+1)])
# q8 = [q3c*(math.e**(-abs(i-820)/60)) for  i in range(len(ref_traj))]
# q9 = q7*q8

# q10 = [q3c*(math.e**(-abs(i-N)/60)) for  i in range(len(ref_traj))]
# q11 = np.array([1 if (800<i)and(i<2000) else 0 for i in range(N+1)])
# q12 = q10*q11

# weight_mats2 = [100*np.diag([10,0,10,0,q2,0])*(math.e**(-abs(i-N)/tau2)) for  i in range(len(ref_traj))]
# weight_mats = [weight_mats[i]+weight_mats2[i] for i in range(len(weight_mats2))]
plt.figure()



q = q3+q6
plt.plot(q)
weight_mats = [100*np.diag([10,0,10,0,10*q[i],5*q[i]]) for  i in range(len(ref_traj))]

# %%
q1c = 1
q2c = 1
tau1 = 20
tau2 = 60

tau3 = 10
tau4 =10
q1 =  np.array([1 if (350<i)and(i<5000) else 0 for i in range(N+1)])
q2 = [q1c*(math.e**(-abs(i-middle)/tau1)) for  i in range(len(ref_traj))]



q4 = np.array([1 if (550<i)and(i<750) else 0 for i in range(N+1)])
q5 = [q2c*(math.e**(-abs(i-600)/tau2)) for  i in range(len(ref_traj))]
q6 = q4*q5

q7 = np.array([1 if (700<i)and(i<5000) else 0 for i in range(N+1)])
q8 = [q2c*(math.e**(-abs(i-N)/tau3)) for  i in range(len(ref_traj))]
q9 = q7*q8


q10 = np.array([1 if (800<i)and(i<900) else 0 for i in range(N+1)])
q11 = [q2c*(math.e**(-abs(i-856)/tau4)) for  i in range(len(ref_traj))]
q12 = q10*q11

q = q1*q2+q6+q9 + q12


856


weight_mats = [100*np.diag([10,0,10,0,10*q[i],0.5*q[i]]) for  i in range(len(ref_traj))]
# weight_mats2 = [100*np.diag([10,0,10,0,q2,0])*(math.e**(-abs(i-N)/tau2)) for  i in range(len(ref_traj))]
# weight_mats = [weight_mats[i]+weight_mats2[i] for i in range(len(weight_mats2))]
plt.figure()
plt.plot(np.sqrt(q))

# %%
ilqr_traj_ctrl = iLQR_Track_Controller(R=1.01, dt=0.01)
ilqr_traj_ctrl.build_iLQR_tracking(ref_traj, weight_mats, robot)
x0 = ref_traj[0]
res = ilqr_traj_ctrl.get_rule(x0, u_init,n_itrs = 150, tol = 1)
z0 = x0
z0[-2:] = [0.0]
x_array = res["x_array_opt"]
u_array = res["u_array_opt"]
k_array = res["k_array_opt"]
K_array = res["K_array_opt"]
def ilqr_controller(state,i):
    ut = K_array[i].dot(state-x_array[i]) + k_array[i] + u_array[i]
    return ut.T
t, state, u = robot.simulate(z0,ilqr_controller, horizon_length, disturbance = False)
# Out:
# Reject the control perturbation. Increase the regularization term.
# Reject the control perturbation. Increase the regularization term.
# Iteration (3,):	J = 3026959.640;	norm_k = 48.156;	reg = 0.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (5,):	J = 2755256.836;	norm_k = 6.470;	reg = 0.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (7,):	J = 2197889.281;	norm_k = 7.094;	reg = 0.000
# Reject the control perturbation. Increase the regularization term.
# Reject the control perturbation. Increase the regularization term.
# Iteration (10,):	J = 2050650.145;	norm_k = 1.733;	reg = 1.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (12,):	J = 1953103.082;	norm_k = 1.504;	reg = 1.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (14,):	J = 1870515.492;	norm_k = 1.450;	reg = 1.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (16,):	J = 1799772.366;	norm_k = 1.301;	reg = 1.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (18,):	J = 1732936.288;	norm_k = 1.205;	reg = 1.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (20,):	J = 1665461.645;	norm_k = 1.178;	reg = 1.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (22,):	J = 1596668.830;	norm_k = 1.188;	reg = 1.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (24,):	J = 1531142.577;	norm_k = 1.219;	reg = 1.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (26,):	J = 1477024.002;	norm_k = 1.279;	reg = 1.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (28,):	J = 1441734.327;	norm_k = 1.375;	reg = 1.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (30,):	J = 1439287.846;	norm_k = 1.494;	reg = 1.000
# Iteration (31,):	J = 1125858.134;	norm_k = 8.703;	reg = 0.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (33,):	J = 949656.948;	norm_k = 7.445;	reg = 0.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (35,):	J = 759543.187;	norm_k = 6.795;	reg = 0.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (37,):	J = 676564.607;	norm_k = 5.500;	reg = 0.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (39,):	J = 522305.183;	norm_k = 5.376;	reg = 0.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (41,):	J = 493097.855;	norm_k = 3.761;	reg = 0.000
# Reject the control perturbation. Increase the regularization term.
# Reject the control perturbation. Increase the regularization term.
# Iteration (44,):	J = 475489.156;	norm_k = 1.020;	reg = 1.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (46,):	J = 470031.100;	norm_k = 0.836;	reg = 1.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (48,):	J = 463786.837;	norm_k = 0.762;	reg = 1.000
# Iteration (49,):	J = 429164.241;	norm_k = 3.582;	reg = 0.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (51,):	J = 396508.790;	norm_k = 3.087;	reg = 0.000
# Iteration (52,):	J = 396266.234;	norm_k = 6.261;	reg = -1.000
# Reject the control perturbation. Increase the regularization term.
# Reject the control perturbation. Increase the regularization term.
# Iteration (55,):	J = 373378.894;	norm_k = 2.770;	reg = 0.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (57,):	J = 370734.103;	norm_k = 2.426;	reg = 0.000
# Iteration (58,):	J = 306637.828;	norm_k = 5.565;	reg = -1.000
# Reject the control perturbation. Increase the regularization term.
# Reject the control perturbation. Increase the regularization term.
# Reject the control perturbation. Increase the regularization term.
# Iteration (62,):	J = 294423.214;	norm_k = 0.594;	reg = 1.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (64,):	J = 292877.832;	norm_k = 0.404;	reg = 1.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (66,):	J = 292471.747;	norm_k = 0.345;	reg = 1.000
# Reject the control perturbation. Increase the regularization term.
# Reject the control perturbation. Increase the regularization term.
# Iteration (69,):	J = 291166.013;	norm_k = 0.060;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (71,):	J = 290453.308;	norm_k = 0.049;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (73,):	J = 289881.702;	norm_k = 0.046;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (75,):	J = 289398.137;	norm_k = 0.043;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (77,):	J = 288976.557;	norm_k = 0.041;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (79,):	J = 288599.853;	norm_k = 0.039;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (81,):	J = 288256.476;	norm_k = 0.038;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (83,):	J = 287938.607;	norm_k = 0.037;	reg = 2.000
# Iteration (84,):	J = 287925.426;	norm_k = 0.275;	reg = 1.000
# Reject the control perturbation. Increase the regularization term.
# Reject the control perturbation. Increase the regularization term.
# Iteration (87,):	J = 287127.914;	norm_k = 0.065;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (89,):	J = 286809.700;	norm_k = 0.042;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (91,):	J = 286543.486;	norm_k = 0.037;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (93,):	J = 286297.563;	norm_k = 0.035;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (95,):	J = 286066.289;	norm_k = 0.033;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (97,):	J = 285846.318;	norm_k = 0.032;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (99,):	J = 285635.565;	norm_k = 0.031;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (101,):	J = 285432.661;	norm_k = 0.030;	reg = 2.000
# Iteration (102,):	J = 285420.919;	norm_k = 0.235;	reg = 1.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (104,):	J = 285410.574;	norm_k = 0.275;	reg = 1.000
# Reject the control perturbation. Increase the regularization term.
# Reject the control perturbation. Increase the regularization term.
# Iteration (107,):	J = 284589.773;	norm_k = 0.064;	reg = 2.000
# Iteration (108,):	J = 284585.501;	norm_k = 0.232;	reg = 1.000
# Reject the control perturbation. Increase the regularization term.
# Reject the control perturbation. Increase the regularization term.
# Iteration (111,):	J = 284394.421;	norm_k = 0.036;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (113,):	J = 284225.295;	norm_k = 0.033;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (115,):	J = 284061.291;	norm_k = 0.031;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (117,):	J = 283902.882;	norm_k = 0.029;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (119,):	J = 283749.367;	norm_k = 0.028;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (121,):	J = 283600.114;	norm_k = 0.028;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (123,):	J = 283454.635;	norm_k = 0.027;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (125,):	J = 283312.563;	norm_k = 0.027;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (127,):	J = 283173.617;	norm_k = 0.026;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (129,):	J = 283037.571;	norm_k = 0.026;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (131,):	J = 282904.233;	norm_k = 0.026;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (133,):	J = 282773.429;	norm_k = 0.025;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (135,):	J = 282644.999;	norm_k = 0.025;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (137,):	J = 282518.788;	norm_k = 0.025;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (139,):	J = 282394.654;	norm_k = 0.024;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (141,):	J = 282272.460;	norm_k = 0.024;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (143,):	J = 282152.081;	norm_k = 0.024;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (145,):	J = 282033.402;	norm_k = 0.024;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (147,):	J = 281916.319;	norm_k = 0.023;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (149,):	J = 281800.738;	norm_k = 0.023;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (151,):	J = 281686.572;	norm_k = 0.023;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (153,):	J = 281573.745;	norm_k = 0.023;	reg = 2.000
# Iteration (154,):	J = 281572.454;	norm_k = 0.189;	reg = 1.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (156,):	J = 281448.258;	norm_k = 0.241;	reg = 1.000
# Reject the control perturbation. Increase the regularization term.
# Reject the control perturbation. Increase the regularization term.
# Iteration (159,):	J = 281023.153;	norm_k = 0.053;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (161,):	J = 280930.633;	norm_k = 0.030;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (163,):	J = 280833.510;	norm_k = 0.027;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (165,):	J = 280736.949;	norm_k = 0.026;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (167,):	J = 280641.829;	norm_k = 0.025;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (169,):	J = 280548.042;	norm_k = 0.024;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (171,):	J = 280455.335;	norm_k = 0.023;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (173,):	J = 280363.504;	norm_k = 0.023;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (175,):	J = 280272.409;	norm_k = 0.023;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (177,):	J = 280181.961;	norm_k = 0.022;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (179,):	J = 280092.105;	norm_k = 0.022;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (181,):	J = 280002.806;	norm_k = 0.022;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (183,):	J = 279914.044;	norm_k = 0.022;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (185,):	J = 279825.803;	norm_k = 0.022;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (187,):	J = 279738.073;	norm_k = 0.021;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (189,):	J = 279650.843;	norm_k = 0.021;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (191,):	J = 279564.104;	norm_k = 0.021;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (193,):	J = 279477.845;	norm_k = 0.021;	reg = 2.000
# Iteration (194,):	J = 279465.670;	norm_k = 0.173;	reg = 1.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (196,):	J = 279338.800;	norm_k = 0.231;	reg = 1.000
# Reject the control perturbation. Increase the regularization term.
# Reject the control perturbation. Increase the regularization term.
# Iteration (199,):	J = 279075.955;	norm_k = 0.050;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (201,):	J = 279010.580;	norm_k = 0.030;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (203,):	J = 278942.573;	norm_k = 0.026;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (205,):	J = 278872.009;	norm_k = 0.025;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (207,):	J = 278800.450;	norm_k = 0.023;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (209,):	J = 278728.478;	norm_k = 0.023;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (211,):	J = 278656.292;	norm_k = 0.022;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (213,):	J = 278583.998;	norm_k = 0.021;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (215,):	J = 278511.676;	norm_k = 0.021;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (217,):	J = 278439.398;	norm_k = 0.021;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (219,):	J = 278367.229;	norm_k = 0.021;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (221,):	J = 278295.223;	norm_k = 0.020;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (223,):	J = 278223.424;	norm_k = 0.020;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (225,):	J = 278151.867;	norm_k = 0.020;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (227,):	J = 278080.576;	norm_k = 0.020;	reg = 2.000
# Iteration (228,):	J = 278080.288;	norm_k = 0.163;	reg = 1.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (230,):	J = 277960.215;	norm_k = 0.226;	reg = 1.000
# Reject the control perturbation. Increase the regularization term.
# Reject the control perturbation. Increase the regularization term.
# Iteration (233,):	J = 277779.782;	norm_k = 0.049;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (235,):	J = 277730.409;	norm_k = 0.030;	reg = 2.000
# Reject the control perturbation. Increase the regularization term.
# Iteration (237,):	J = 277679.837;	norm_k = 0.026;	reg = 2.000

# %%
# we can plot the results
plt.figure(figsize=[9,6])

plt.subplot(2,3,1)
plt.plot(t, state[0,:])
plt.plot(t, state_desired[0,:])
plt.legend(['X'])

plt.subplot(2,3,2)
plt.plot(t, state[2,:])
plt.plot(t, state_desired[2,:])
plt.legend(['Y'])

plt.subplot(2,3,3)
plt.plot(t, state[4,:])
plt.plot(t, state_desired[4,:])
plt.legend(["theta"])

plt.subplot(2,3,4)
plt.plot(t, state[1,:])
plt.plot(t, state_desired[1,:])
plt.legend(['Vx'])
plt.xlabel('Time [s]')

plt.subplot(2,3,5)
plt.plot(t, state[3,:])
plt.plot(t, state_desired[3,:])
plt.legend(['Vy'])
plt.xlabel('Time [s]')

plt.subplot(2,3,6)
plt.plot(t, state[5,:])
plt.plot(t, state_desired[5,:])
plt.legend(['omega'])
plt.xlabel('Time [s]')

# we can also plot the control
plt.figure()
plt.plot(t[:-1], u.T)
plt.legend(['u1', 'u2'])
plt.xlabel('Time [s]')

# %%
state[4,2:].argmin()
# Out:
# 95

# %%
robot.animate_robot(state,u)
# Out:
# <video width="612" height="612" controls autoplay loop>
#   <source type="video/mp4" src="...
